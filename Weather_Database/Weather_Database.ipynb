# %%
# Import the dependencies.
import numpy as np
from citipy import citipy
import pandas as pd
# Import the API key.
from config import weather_api_key
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Import the requests library.
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | lumeje
# Processing Record 4 of Set 1 | arraial do cabo
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | kwekwe
# Processing Record 7 of Set 1 | bredasdorp
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | uwayl
# City not found. Skipping...
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | sitka
# Processing Record 13 of Set 1 | barrow
# Processing Record 14 of Set 1 | kushmurun
# Processing Record 15 of Set 1 | avarua
# Processing Record 16 of Set 1 | galveston
# Processing Record 17 of Set 1 | atar
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | cariacica
# Processing Record 20 of Set 1 | dikson
# Processing Record 21 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 1 | longyearbyen
# Processing Record 23 of Set 1 | hilo
# Processing Record 24 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 1 | clyde river
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 1 | kavieng
# Processing Record 29 of Set 1 | tautira
# Processing Record 30 of Set 1 | lakhdenpokhya
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | sven
# Processing Record 33 of Set 1 | chase
# Processing Record 34 of Set 1 | new norfolk
# Processing Record 35 of Set 1 | areia branca
# Processing Record 36 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 1 | santa pola
# Processing Record 38 of Set 1 | kizukuri
# Processing Record 39 of Set 1 | butaritari
# Processing Record 40 of Set 1 | yeppoon
# Processing Record 41 of Set 1 | formosa do rio preto
# Processing Record 42 of Set 1 | wajima
# Processing Record 43 of Set 1 | beyneu
# Processing Record 44 of Set 1 | santo tomas
# Processing Record 45 of Set 1 | port alfred
# Processing Record 46 of Set 1 | fukue
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | sorsk
# Processing Record 49 of Set 1 | kaitangata
# Processing Record 50 of Set 1 | chuy
# Processing Record 1 of Set 2 | bambous virieux
# Processing Record 2 of Set 2 | waddan
# Processing Record 3 of Set 2 | opuwo
# Processing Record 4 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 5 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 2 | moree
# Processing Record 7 of Set 2 | pangai
# Processing Record 8 of Set 2 | tilichiki
# Processing Record 9 of Set 2 | thompson
# Processing Record 10 of Set 2 | vardo
# Processing Record 11 of Set 2 | atuona
# Processing Record 12 of Set 2 | saint-joseph
# Processing Record 13 of Set 2 | jacareacanga
# Processing Record 14 of Set 2 | gravdal
# Processing Record 15 of Set 2 | bambanglipuro
# Processing Record 16 of Set 2 | san pedro
# Processing Record 17 of Set 2 | castro
# Processing Record 18 of Set 2 | chokurdakh
# Processing Record 19 of Set 2 | turbat
# Processing Record 20 of Set 2 | goderich
# Processing Record 21 of Set 2 | saskylakh
# Processing Record 22 of Set 2 | puerto ayora
# Processing Record 23 of Set 2 | umm lajj
# Processing Record 24 of Set 2 | dudinka
# Processing Record 25 of Set 2 | buala
# Processing Record 26 of Set 2 | kalmunai
# Processing Record 27 of Set 2 | faanui
# Processing Record 28 of Set 2 | necochea
# Processing Record 29 of Set 2 | suntar
# Processing Record 30 of Set 2 | qasigiannguit
# Processing Record 31 of Set 2 | burns lake
# Processing Record 32 of Set 2 | khatanga
# Processing Record 33 of Set 2 | aksha
# Processing Record 34 of Set 2 | comodoro rivadavia
# Processing Record 35 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 36 of Set 2 | port hardy
# Processing Record 37 of Set 2 | cabo san lucas
# Processing Record 38 of Set 2 | manokwari
# Processing Record 39 of Set 2 | mayo
# Processing Record 40 of Set 2 | georgetown
# Processing Record 41 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 2 | jitra
# Processing Record 43 of Set 2 | belaya gora
# Processing Record 44 of Set 2 | punta arenas
# Processing Record 45 of Set 2 | kodiak
# Processing Record 46 of Set 2 | pevek
# Processing Record 47 of Set 2 | hermanus
# Processing Record 48 of Set 2 | serebryansk
# Processing Record 49 of Set 2 | ostrovnoy
# Processing Record 50 of Set 2 | chanika
# Processing Record 1 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 3 | yerbogachen
# Processing Record 3 of Set 3 | hasaki
# Processing Record 4 of Set 3 | ushuaia
# Processing Record 5 of Set 3 | baisha
# Processing Record 6 of Set 3 | san felipe
# Processing Record 7 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 3 | la ronge
# Processing Record 9 of Set 3 | nioro
# Processing Record 10 of Set 3 | arman
# Processing Record 11 of Set 3 | tucupita
# Processing Record 12 of Set 3 | axim
# Processing Record 13 of Set 3 | nyurba
# Processing Record 14 of Set 3 | mbekenyera
# Processing Record 15 of Set 3 | egvekinot
# Processing Record 16 of Set 3 | saint anthony
# Processing Record 17 of Set 3 | verkhnevilyuysk
# Processing Record 18 of Set 3 | nunoa
# Processing Record 19 of Set 3 | marzuq
# Processing Record 20 of Set 3 | seoul
# Processing Record 21 of Set 3 | victoria
# Processing Record 22 of Set 3 | gaoual
# Processing Record 23 of Set 3 | bontang
# Processing Record 24 of Set 3 | stornoway
# Processing Record 25 of Set 3 | fairbanks
# Processing Record 26 of Set 3 | tiksi
# Processing Record 27 of Set 3 | casambalangan
# Processing Record 28 of Set 3 | puri
# Processing Record 29 of Set 3 | nikolskoye
# Processing Record 30 of Set 3 | marand
# Processing Record 31 of Set 3 | mahebourg
# Processing Record 32 of Set 3 | dwarka
# Processing Record 33 of Set 3 | port lincoln
# Processing Record 34 of Set 3 | katsuura
# Processing Record 35 of Set 3 | iqaluit
# Processing Record 36 of Set 3 | deputatskiy
# Processing Record 37 of Set 3 | provideniya
# Processing Record 38 of Set 3 | kovylkino
# Processing Record 39 of Set 3 | carutapera
# Processing Record 40 of Set 3 | saint-philippe
# Processing Record 41 of Set 3 | aguimes
# Processing Record 42 of Set 3 | tuktoyaktuk
# Processing Record 43 of Set 3 | qaanaaq
# Processing Record 44 of Set 3 | paiho
# City not found. Skipping...
# Processing Record 45 of Set 3 | east london
# Processing Record 46 of Set 3 | kazerun
# Processing Record 47 of Set 3 | banda aceh
# Processing Record 48 of Set 3 | hobart
# Processing Record 49 of Set 3 | tongliao
# Processing Record 50 of Set 3 | bitkine
# Processing Record 1 of Set 4 | krasnoselkup
# Processing Record 2 of Set 4 | ipixuna
# Processing Record 3 of Set 4 | severo-kurilsk
# Processing Record 4 of Set 4 | chapais
# Processing Record 5 of Set 4 | vanimo
# Processing Record 6 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 4 | kapaa
# Processing Record 8 of Set 4 | pangnirtung
# Processing Record 9 of Set 4 | hobyo
# Processing Record 10 of Set 4 | safita
# Processing Record 11 of Set 4 | otradinskiy
# City not found. Skipping...
# Processing Record 12 of Set 4 | geraldton
# Processing Record 13 of Set 4 | harper
# Processing Record 14 of Set 4 | fort nelson
# Processing Record 15 of Set 4 | souillac
# Processing Record 16 of Set 4 | espanola
# Processing Record 17 of Set 4 | morondava
# Processing Record 18 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 4 | anadyr
# Processing Record 20 of Set 4 | tasiilaq
# Processing Record 21 of Set 4 | maarianhamina
# Processing Record 22 of Set 4 | port elizabeth
# Processing Record 23 of Set 4 | cherskiy
# Processing Record 24 of Set 4 | acajutla
# Processing Record 25 of Set 4 | hambantota
# Processing Record 26 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 4 | kokopo
# Processing Record 28 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 4 | tonantins
# Processing Record 30 of Set 4 | bar harbor
# Processing Record 31 of Set 4 | tretten
# Processing Record 32 of Set 4 | coquimbo
# Processing Record 33 of Set 4 | quatre cocos
# Processing Record 34 of Set 4 | saint george
# Processing Record 35 of Set 4 | khorixas
# Processing Record 36 of Set 4 | lorengau
# Processing Record 37 of Set 4 | grand-santi
# Processing Record 38 of Set 4 | torbay
# Processing Record 39 of Set 4 | lebu
# Processing Record 40 of Set 4 | tambo grande
# Processing Record 41 of Set 4 | astipalaia
# City not found. Skipping...
# Processing Record 42 of Set 4 | ahipara
# Processing Record 43 of Set 4 | okhotsk
# Processing Record 44 of Set 4 | nome
# Processing Record 45 of Set 4 | namibe
# Processing Record 46 of Set 4 | front royal
# Processing Record 47 of Set 4 | san francisco
# Processing Record 48 of Set 4 | utiel
# Processing Record 49 of Set 4 | pisco
# Processing Record 50 of Set 4 | kavaratti
# Processing Record 1 of Set 5 | carnarvon
# Processing Record 2 of Set 5 | tanete
# Processing Record 3 of Set 5 | lagoa
# Processing Record 4 of Set 5 | tuatapere
# Processing Record 5 of Set 5 | kaduqli
# Processing Record 6 of Set 5 | pemangkat
# Processing Record 7 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 8 of Set 5 | lodwar
# Processing Record 9 of Set 5 | dingle
# Processing Record 10 of Set 5 | ulety
# Processing Record 11 of Set 5 | tisovec
# Processing Record 12 of Set 5 | vila franca do campo
# Processing Record 13 of Set 5 | parana
# Processing Record 14 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 5 | ponta do sol
# Processing Record 16 of Set 5 | la baule-escoublac
# Processing Record 17 of Set 5 | leningradskiy
# Processing Record 18 of Set 5 | havre-saint-pierre
# Processing Record 19 of Set 5 | kulhudhuffushi
# Processing Record 20 of Set 5 | ribeira grande
# Processing Record 21 of Set 5 | ancud
# Processing Record 22 of Set 5 | sarakhs
# Processing Record 23 of Set 5 | normandin
# Processing Record 24 of Set 5 | olafsvik
# Processing Record 25 of Set 5 | rawson
# Processing Record 26 of Set 5 | lyubim
# Processing Record 27 of Set 5 | san patricio
# Processing Record 28 of Set 5 | valparaiso
# Processing Record 29 of Set 5 | saldanha
# Processing Record 30 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 31 of Set 5 | nishihara
# Processing Record 32 of Set 5 | carbondale
# Processing Record 33 of Set 5 | svetlyy
# Processing Record 34 of Set 5 | jumla
# Processing Record 35 of Set 5 | molaoi
# Processing Record 36 of Set 5 | namatanai
# Processing Record 37 of Set 5 | bhikhi
# Processing Record 38 of Set 5 | tual
# Processing Record 39 of Set 5 | samarai
# Processing Record 40 of Set 5 | sevierville
# Processing Record 41 of Set 5 | menongue
# Processing Record 42 of Set 5 | zabol
# Processing Record 43 of Set 5 | thinadhoo
# Processing Record 44 of Set 5 | manubul
# Processing Record 45 of Set 5 | alenquer
# Processing Record 46 of Set 5 | arica
# Processing Record 47 of Set 5 | langnau
# Processing Record 48 of Set 5 | filadelfia
# Processing Record 49 of Set 5 | kalangala
# Processing Record 50 of Set 5 | airai
# Processing Record 1 of Set 6 | stekolnyy
# City not found. Skipping...
# Processing Record 2 of Set 6 | tabas
# Processing Record 3 of Set 6 | plettenberg bay
# Processing Record 4 of Set 6 | khasan
# Processing Record 5 of Set 6 | teluk nibung
# Processing Record 6 of Set 6 | isla vista
# Processing Record 7 of Set 6 | cabedelo
# Processing Record 8 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 9 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 10 of Set 6 | adrar
# Processing Record 11 of Set 6 | eagle pass
# Processing Record 12 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 6 | jalu
# Processing Record 14 of Set 6 | esperance
# Processing Record 15 of Set 6 | mount gambier
# Processing Record 16 of Set 6 | codrington
# Processing Record 17 of Set 6 | paradwip
# City not found. Skipping...
# Processing Record 18 of Set 6 | eganville
# Processing Record 19 of Set 6 | marsa matruh
# Processing Record 20 of Set 6 | alihe
# Processing Record 21 of Set 6 | sovetsk
# Processing Record 22 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 6 | gold coast
# Processing Record 24 of Set 6 | manzil salim
# Processing Record 25 of Set 6 | dali
# Processing Record 26 of Set 6 | sao joao da barra
# Processing Record 27 of Set 6 | upernavik
# Processing Record 28 of Set 6 | nuuk
# Processing Record 29 of Set 6 | coahuayana
# Processing Record 30 of Set 6 | lata
# Processing Record 31 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 6 | port augusta
# Processing Record 33 of Set 6 | vostok
# Processing Record 34 of Set 6 | koyelga
# Processing Record 35 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 6 | lannion
# Processing Record 37 of Set 6 | kandrian
# Processing Record 38 of Set 6 | guerrero negro
# Processing Record 39 of Set 6 | half moon bay
# Processing Record 40 of Set 6 | oriximina
# Processing Record 41 of Set 6 | cidreira
# Processing Record 42 of Set 6 | margate
# Processing Record 43 of Set 6 | grand gaube
# Processing Record 44 of Set 6 | kefamenanu
# Processing Record 45 of Set 6 | timra
# Processing Record 46 of Set 6 | richards bay
# Processing Record 47 of Set 6 | alice springs
# Processing Record 48 of Set 6 | flinders
# Processing Record 49 of Set 6 | iberia
# Processing Record 50 of Set 6 | shubarshi
# Processing Record 1 of Set 7 | raudeberg
# Processing Record 2 of Set 7 | camden
# Processing Record 3 of Set 7 | mount darwin
# Processing Record 4 of Set 7 | zverinogolovskoye
# Processing Record 5 of Set 7 | surt
# Processing Record 6 of Set 7 | les cayes
# Processing Record 7 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 8 of Set 7 | kovdor
# Processing Record 9 of Set 7 | shibetsu
# Processing Record 10 of Set 7 | kirakira
# Processing Record 11 of Set 7 | ambon
# Processing Record 12 of Set 7 | polovinnoye
# Processing Record 13 of Set 7 | luangwa
# Processing Record 14 of Set 7 | lexington
# Processing Record 15 of Set 7 | saint-georges
# Processing Record 16 of Set 7 | salekhard
# Processing Record 17 of Set 7 | kahului
# Processing Record 18 of Set 7 | mahibadhoo
# Processing Record 19 of Set 7 | am timan
# Processing Record 20 of Set 7 | luanda
# Processing Record 21 of Set 7 | taltal
# Processing Record 22 of Set 7 | kiunga
# Processing Record 23 of Set 7 | makakilo city
# Processing Record 24 of Set 7 | san vicente
# Processing Record 25 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 7 | russell
# Processing Record 27 of Set 7 | inta
# Processing Record 28 of Set 7 | pitimbu
# Processing Record 29 of Set 7 | vilcun
# Processing Record 30 of Set 7 | sibolga
# Processing Record 31 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 32 of Set 7 | marienburg
# Processing Record 33 of Set 7 | miyako
# Processing Record 34 of Set 7 | cermik
# Processing Record 35 of Set 7 | bereznik
# Processing Record 36 of Set 7 | riyadh
# Processing Record 37 of Set 7 | artyom
# Processing Record 38 of Set 7 | muros
# Processing Record 39 of Set 7 | coro
# Processing Record 40 of Set 7 | pietersburg
# Processing Record 41 of Set 7 | ishigaki
# Processing Record 42 of Set 7 | antalaha
# Processing Record 43 of Set 7 | phan thiet
# Processing Record 44 of Set 7 | vila velha
# Processing Record 45 of Set 7 | koumac
# Processing Record 46 of Set 7 | port blair
# Processing Record 47 of Set 7 | mount isa
# Processing Record 48 of Set 7 | talnakh
# Processing Record 49 of Set 7 | boa vista
# Processing Record 50 of Set 7 | komyshnya
# Processing Record 1 of Set 8 | helena
# Processing Record 2 of Set 8 | asau
# Processing Record 3 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 8 | shimoda
# Processing Record 5 of Set 8 | kuah
# Processing Record 6 of Set 8 | golkoy
# Processing Record 7 of Set 8 | herat
# Processing Record 8 of Set 8 | kpandu
# Processing Record 9 of Set 8 | tucuma
# Processing Record 10 of Set 8 | myitkyina
# Processing Record 11 of Set 8 | mandal
# Processing Record 12 of Set 8 | sao sepe
# Processing Record 13 of Set 8 | karema
# Processing Record 14 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 8 | guiyang
# Processing Record 16 of Set 8 | zaraza
# Processing Record 17 of Set 8 | sinnamary
# Processing Record 18 of Set 8 | ocampo
# Processing Record 19 of Set 8 | sisimiut
# Processing Record 20 of Set 8 | bandarbeyla
# Processing Record 21 of Set 8 | college
# Processing Record 22 of Set 8 | yatou
# Processing Record 23 of Set 8 | batemans bay
# Processing Record 24 of Set 8 | saryg-sep
# Processing Record 25 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 8 | vitim
# Processing Record 27 of Set 8 | orodara
# Processing Record 28 of Set 8 | dekar
# Processing Record 29 of Set 8 | parkersburg
# Processing Record 30 of Set 8 | naze
# Processing Record 31 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 32 of Set 8 | matane
# Processing Record 33 of Set 8 | ambagarh chauki
# Processing Record 34 of Set 8 | mar del plata
# Processing Record 35 of Set 8 | aitape
# Processing Record 36 of Set 8 | guajara-mirim
# City not found. Skipping...
# Processing Record 37 of Set 8 | mehamn
# Processing Record 38 of Set 8 | ginir
# Processing Record 39 of Set 8 | paka
# Processing Record 40 of Set 8 | araouane
# Processing Record 41 of Set 8 | gidole
# Processing Record 42 of Set 8 | quelimane
# Processing Record 43 of Set 8 | maceio
# Processing Record 44 of Set 8 | lekoni
# Processing Record 45 of Set 8 | paamiut
# Processing Record 46 of Set 8 | mpika
# Processing Record 47 of Set 8 | clarence town
# Processing Record 48 of Set 8 | inirida
# Processing Record 49 of Set 8 | tynda
# Processing Record 50 of Set 8 | scottsbluff
# Processing Record 1 of Set 9 | labuhan
# Processing Record 2 of Set 9 | vytegra
# Processing Record 3 of Set 9 | emba
# Processing Record 4 of Set 9 | hualmay
# Processing Record 5 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 6 of Set 9 | dasoguz
# Processing Record 7 of Set 9 | pinotepa de don luis
# Processing Record 8 of Set 9 | matara
# Processing Record 9 of Set 9 | paysandu
# Processing Record 10 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 9 | oga
# Processing Record 12 of Set 9 | biltine
# Processing Record 13 of Set 9 | jinchang
# Processing Record 14 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 15 of Set 9 | los llanos de aridane
# Processing Record 16 of Set 9 | clinton
# Processing Record 17 of Set 9 | klaksvik
# Processing Record 18 of Set 9 | vao
# Processing Record 19 of Set 9 | yulara
# Processing Record 20 of Set 9 | cap-aux-meules
# Processing Record 21 of Set 9 | severnyy-kospashskiy
# Processing Record 22 of Set 9 | isoka
# Processing Record 23 of Set 9 | ilulissat
# Processing Record 24 of Set 9 | laguna
# Processing Record 25 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 26 of Set 9 | monaghan
# Processing Record 27 of Set 9 | padang
# Processing Record 28 of Set 9 | bathsheba
# Processing Record 29 of Set 9 | kalinagar
# Processing Record 30 of Set 9 | kununurra
# Processing Record 31 of Set 9 | fushun
# Processing Record 32 of Set 9 | svobodnyy
# Processing Record 33 of Set 9 | alofi
# Processing Record 34 of Set 9 | high rock
# Processing Record 35 of Set 9 | kruisfontein
# Processing Record 36 of Set 9 | kigonsera
# Processing Record 37 of Set 9 | tigil
# Processing Record 38 of Set 9 | lalomanu
# City not found. Skipping...
# Processing Record 39 of Set 9 | candido mendes
# Processing Record 40 of Set 9 | simbahan
# Processing Record 41 of Set 9 | sur
# Processing Record 42 of Set 9 | koindu
# Processing Record 43 of Set 9 | srednekolymsk
# Processing Record 44 of Set 9 | coihaique
# Processing Record 45 of Set 9 | piacenza
# Processing Record 46 of Set 9 | luena
# Processing Record 47 of Set 9 | san quintin
# Processing Record 48 of Set 9 | sosnovo-ozerskoye
# Processing Record 49 of Set 9 | charlestown
# Processing Record 50 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 1 of Set 10 | dunedin
# Processing Record 2 of Set 10 | tolaga bay
# Processing Record 3 of Set 10 | colares
# Processing Record 4 of Set 10 | juifang
# City not found. Skipping...
# Processing Record 5 of Set 10 | narsaq
# Processing Record 6 of Set 10 | nefteyugansk
# Processing Record 7 of Set 10 | rafaela
# Processing Record 8 of Set 10 | lavrentiya
# Processing Record 9 of Set 10 | gizo
# Processing Record 10 of Set 10 | simao
# Processing Record 11 of Set 10 | hayden
# Processing Record 12 of Set 10 | katrineholm
# Processing Record 13 of Set 10 | bardiyah
# Processing Record 14 of Set 10 | koygorodok
# Processing Record 15 of Set 10 | mao
# Processing Record 16 of Set 10 | esso
# Processing Record 17 of Set 10 | samana
# Processing Record 18 of Set 10 | skibotn
# Processing Record 19 of Set 10 | itarema
# Processing Record 20 of Set 10 | luderitz
# Processing Record 21 of Set 10 | tanout
# Processing Record 22 of Set 10 | andros town
# Processing Record 23 of Set 10 | eucaliptus
# Processing Record 24 of Set 10 | hokitika
# Processing Record 25 of Set 10 | aklavik
# Processing Record 26 of Set 10 | vagay
# Processing Record 27 of Set 10 | southbridge
# Processing Record 28 of Set 10 | odweyne
# Processing Record 29 of Set 10 | isangel
# Processing Record 30 of Set 10 | ormond beach
# Processing Record 31 of Set 10 | ust-kuyga
# Processing Record 32 of Set 10 | lasa
# Processing Record 33 of Set 10 | okato
# Processing Record 34 of Set 10 | roma
# Processing Record 35 of Set 10 | amuntai
# Processing Record 36 of Set 10 | ketchikan
# Processing Record 37 of Set 10 | charters towers
# Processing Record 38 of Set 10 | kerrville
# Processing Record 39 of Set 10 | heihe
# Processing Record 40 of Set 10 | watertown
# Processing Record 41 of Set 10 | norman wells
# Processing Record 42 of Set 10 | srivardhan
# Processing Record 43 of Set 10 | katherine
# Processing Record 44 of Set 10 | hay river
# Processing Record 45 of Set 10 | launceston
# Processing Record 46 of Set 10 | tessalit
# Processing Record 47 of Set 10 | klyuchi
# Processing Record 48 of Set 10 | dauphin
# Processing Record 49 of Set 10 | gundorovskiy
# Processing Record 50 of Set 10 | bonen
# Processing Record 1 of Set 11 | bethel
# Processing Record 2 of Set 11 | mudgee
# Processing Record 3 of Set 11 | san diego de los banos
# Processing Record 4 of Set 11 | marawi
# Processing Record 5 of Set 11 | mareeba
# Processing Record 6 of Set 11 | sawakin
# Processing Record 7 of Set 11 | novyy urengoy
# Processing Record 8 of Set 11 | nizhneangarsk
# Processing Record 9 of Set 11 | slave lake
# Processing Record 10 of Set 11 | bonavista
# Processing Record 11 of Set 11 | nouadhibou
# Processing Record 12 of Set 11 | moose factory
# Processing Record 13 of Set 11 | san jose
# Processing Record 14 of Set 11 | agva
# City not found. Skipping...
# Processing Record 15 of Set 11 | susuman
# Processing Record 16 of Set 11 | nanakuli
# Processing Record 17 of Set 11 | tromso
# Processing Record 18 of Set 11 | la palma del condado
# Processing Record 19 of Set 11 | te anau
# Processing Record 20 of Set 11 | isiolo
# Processing Record 21 of Set 11 | nanortalik
# Processing Record 22 of Set 11 | bilibino
# Processing Record 23 of Set 11 | badaojiang
# City not found. Skipping...
# Processing Record 24 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 25 of Set 11 | liverpool
# Processing Record 26 of Set 11 | pandan
# Processing Record 27 of Set 11 | fortuna
# Processing Record 28 of Set 11 | nanton
# Processing Record 29 of Set 11 | lucapa
# Processing Record 30 of Set 11 | otavi
# Processing Record 31 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 32 of Set 11 | zhangjiakou
# Processing Record 33 of Set 11 | san cristobal
# Processing Record 34 of Set 11 | itaituba
# Processing Record 35 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 36 of Set 11 | bengkulu
# Processing Record 37 of Set 11 | tari
# Processing Record 38 of Set 11 | uthal
# Processing Record 39 of Set 11 | nokaneng
# Processing Record 40 of Set 11 | muzhi
# Processing Record 41 of Set 11 | biak
# Processing Record 42 of Set 11 | trenggalek
# Processing Record 43 of Set 11 | portland
# Processing Record 44 of Set 11 | les escoumins
# Processing Record 45 of Set 11 | pemba
# Processing Record 46 of Set 11 | vicuna
# Processing Record 47 of Set 11 | adilcevaz
# Processing Record 48 of Set 11 | sozimskiy
# Processing Record 49 of Set 11 | salalah
# Processing Record 50 of Set 11 | komsomolskiy
# Processing Record 1 of Set 12 | kattivakkam
# Processing Record 2 of Set 12 | mutsu
# Processing Record 3 of Set 12 | chipiona
# Processing Record 4 of Set 12 | hunucma
# Processing Record 5 of Set 12 | karasjok
# Processing Record 6 of Set 12 | ust-tsilma
# Processing Record 7 of Set 12 | ondjiva
# Processing Record 8 of Set 12 | olavarria
# Processing Record 9 of Set 12 | port macquarie
# Processing Record 10 of Set 12 | djibo
# Processing Record 11 of Set 12 | shenjiamen
# Processing Record 12 of Set 12 | angoche
# Processing Record 13 of Set 12 | yar-sale
# Processing Record 14 of Set 12 | bodden town
# Processing Record 15 of Set 12 | xai-xai
# Processing Record 16 of Set 12 | imphal
# Processing Record 17 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 18 of Set 12 | silifke
# Processing Record 19 of Set 12 | grafton
# Processing Record 20 of Set 12 | praia da vitoria
# Processing Record 21 of Set 12 | gwanda
# Processing Record 22 of Set 12 | kyra
# Processing Record 23 of Set 12 | la paz
# Processing Record 24 of Set 12 | ankazoabo
# Processing Record 25 of Set 12 | hofn
# Processing Record 26 of Set 12 | dubbo
# Processing Record 27 of Set 12 | touros
# Processing Record 28 of Set 12 | manica
# Processing Record 29 of Set 12 | cockburn town
# Processing Record 30 of Set 12 | chapayevka
# Processing Record 31 of Set 12 | nemuro
# Processing Record 32 of Set 12 | rabat
# Processing Record 33 of Set 12 | hoquiam
# Processing Record 34 of Set 12 | hervey bay
# Processing Record 35 of Set 12 | ascension
# Processing Record 36 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 37 of Set 12 | gulshat
# City not found. Skipping...
# Processing Record 38 of Set 12 | kieta
# Processing Record 39 of Set 12 | chernyshevskiy
# Processing Record 40 of Set 12 | altay
# Processing Record 41 of Set 12 | senmonorom
# City not found. Skipping...
# Processing Record 42 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 43 of Set 12 | peno
# Processing Record 44 of Set 12 | sambava
# Processing Record 45 of Set 12 | cayenne
# Processing Record 46 of Set 12 | amga
# Processing Record 47 of Set 12 | rantoul
# Processing Record 48 of Set 12 | troitsko-pechorsk
# Processing Record 49 of Set 12 | mercedes
# Processing Record 50 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 13 | broome
# Processing Record 2 of Set 13 | magadi
# Processing Record 3 of Set 13 | viedma
# Processing Record 4 of Set 13 | oranjemund
# Processing Record 5 of Set 13 | victor harbor
# Processing Record 6 of Set 13 | kidal
# Processing Record 7 of Set 13 | shemonaikha
# Processing Record 8 of Set 13 | benxi
# Processing Record 9 of Set 13 | cravo norte
# Processing Record 10 of Set 13 | aswan
# Processing Record 11 of Set 13 | victoria point
# Processing Record 12 of Set 13 | evanston
# Processing Record 13 of Set 13 | valle de allende
# Processing Record 14 of Set 13 | ous
# Processing Record 15 of Set 13 | rorvik
# Processing Record 16 of Set 13 | ugoofaaru
# Processing Record 17 of Set 13 | lesogorskiy
# Processing Record 18 of Set 13 | tabialan
# City not found. Skipping...
# Processing Record 19 of Set 13 | codajas
# Processing Record 20 of Set 13 | logresti
# Processing Record 21 of Set 13 | berlevag
# Processing Record 22 of Set 13 | zhigansk
# Processing Record 23 of Set 13 | todos santos
# Processing Record 24 of Set 13 | wakefield
# Processing Record 25 of Set 13 | gebre guracha
# Processing Record 26 of Set 13 | ulladulla
# Processing Record 27 of Set 13 | peterhead
# Processing Record 28 of Set 13 | kuantan
# Processing Record 29 of Set 13 | conway
# Processing Record 30 of Set 13 | zaysan
# Processing Record 31 of Set 13 | neftcala
# Processing Record 32 of Set 13 | shushtar
# Processing Record 33 of Set 13 | san andres
# Processing Record 34 of Set 13 | evensk
# Processing Record 35 of Set 13 | serabu
# Processing Record 36 of Set 13 | lovec
# City not found. Skipping...
# Processing Record 37 of Set 13 | baruun-urt
# Processing Record 38 of Set 13 | northport
# Processing Record 39 of Set 13 | senno
# Processing Record 40 of Set 13 | saint-augustin
# Processing Record 41 of Set 13 | marsh harbour
# Processing Record 42 of Set 13 | otradnoye
# Processing Record 43 of Set 13 | bend
# Processing Record 44 of Set 13 | boralday
# Processing Record 45 of Set 13 | conakry
# Processing Record 46 of Set 13 | barcelona
# Processing Record 47 of Set 13 | mirnyy
# Processing Record 48 of Set 13 | kudahuvadhoo
# Processing Record 49 of Set 13 | la venta del astillero
# Processing Record 50 of Set 13 | oltu
# Processing Record 1 of Set 14 | teguise
# Processing Record 2 of Set 14 | caravelas
# Processing Record 3 of Set 14 | genhe
# Processing Record 4 of Set 14 | mombetsu
# Processing Record 5 of Set 14 | verkhnyaya inta
# Processing Record 6 of Set 14 | saint-pierre
# Processing Record 7 of Set 14 | usoke
# Processing Record 8 of Set 14 | saryozek
# Processing Record 9 of Set 14 | bury saint edmunds
# City not found. Skipping...
# Processing Record 10 of Set 14 | bacolod
# Processing Record 11 of Set 14 | ontario
# Processing Record 12 of Set 14 | lompoc
# Processing Record 13 of Set 14 | northam
# Processing Record 14 of Set 14 | carbonia
# Processing Record 15 of Set 14 | ati
# Processing Record 16 of Set 14 | xingcheng
# Processing Record 17 of Set 14 | bhadrachalam
# Processing Record 18 of Set 14 | halle
# Processing Record 19 of Set 14 | kolimvari
# City not found. Skipping...
# Processing Record 20 of Set 14 | priargunsk
# Processing Record 21 of Set 14 | samfya
# Processing Record 22 of Set 14 | morehead
# Processing Record 23 of Set 14 | lovington
# Processing Record 24 of Set 14 | eston
# Processing Record 25 of Set 14 | acapulco
# Processing Record 26 of Set 14 | kapuskasing
# Processing Record 27 of Set 14 | staroutkinsk
# Processing Record 28 of Set 14 | takaka
# Processing Record 29 of Set 14 | smidovich
# Processing Record 30 of Set 14 | abu zabad
# Processing Record 31 of Set 14 | pathalgaon
# Processing Record 32 of Set 14 | tangzhai
# Processing Record 33 of Set 14 | gubkinskiy
# Processing Record 34 of Set 14 | concordia
# Processing Record 35 of Set 14 | asuncion nochixtlan
# Processing Record 36 of Set 14 | astana
# Processing Record 37 of Set 14 | fare
# Processing Record 38 of Set 14 | sao filipe
# Processing Record 39 of Set 14 | beloha
# Processing Record 40 of Set 14 | the valley
# Processing Record 41 of Set 14 | yumen
# Processing Record 42 of Set 14 | yaan
# Processing Record 43 of Set 14 | camargo
# Processing Record 44 of Set 14 | ereymentau
# Processing Record 45 of Set 14 | kasongo
# Processing Record 46 of Set 14 | talaya
# Processing Record 47 of Set 14 | taoudenni
# Processing Record 48 of Set 14 | kutum
# Processing Record 49 of Set 14 | xuddur
# Processing Record 50 of Set 14 | pimentel
# Processing Record 1 of Set 15 | irara
# Processing Record 2 of Set 15 | chintamani
# Processing Record 3 of Set 15 | ilihan
# Processing Record 4 of Set 15 | vedasandur
# Processing Record 5 of Set 15 | tura
# Processing Record 6 of Set 15 | sorland
# Processing Record 7 of Set 15 | salym
# Processing Record 8 of Set 15 | vestmannaeyjar
# Processing Record 9 of Set 15 | houma
# Processing Record 10 of Set 15 | hami
# Processing Record 11 of Set 15 | rehoboth
# Processing Record 12 of Set 15 | gat
# Processing Record 13 of Set 15 | gunupur
# Processing Record 14 of Set 15 | grindavik
# Processing Record 15 of Set 15 | balkanabat
# Processing Record 16 of Set 15 | port hedland
# Processing Record 17 of Set 15 | tocopilla
# Processing Record 18 of Set 15 | kisangani
# Processing Record 19 of Set 15 | mogadishu
# Processing Record 20 of Set 15 | sjenica
# Processing Record 21 of Set 15 | cascais
# Processing Record 22 of Set 15 | parintins
# Processing Record 23 of Set 15 | benguela
# Processing Record 24 of Set 15 | napoleon
# Processing Record 25 of Set 15 | huarmey
# Processing Record 26 of Set 15 | deh rawud
# City not found. Skipping...
# Processing Record 27 of Set 15 | mugur-aksy
# Processing Record 28 of Set 15 | kailua
# Processing Record 29 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 30 of Set 15 | saintes
# Processing Record 31 of Set 15 | jibuti
# Processing Record 32 of Set 15 | vaitape
# Processing Record 33 of Set 15 | xunchang
# Processing Record 34 of Set 15 | winsum
# Processing Record 35 of Set 15 | oranjestad
# Processing Record 36 of Set 15 | qui nhon
# Processing Record 37 of Set 15 | dhidhdhoo
# Processing Record 38 of Set 15 | bouza
# Processing Record 39 of Set 15 | formosa
# Processing Record 40 of Set 15 | areosa
# Processing Record 41 of Set 15 | haines junction
# Processing Record 42 of Set 15 | la ciotat
# Processing Record 43 of Set 15 | yingshang
# City not found. Skipping...
# Processing Record 44 of Set 15 | constitucion
# Processing Record 45 of Set 15 | hamilton
# Processing Record 46 of Set 15 | chanute
# Processing Record 47 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 15 | navahrudak
# Processing Record 49 of Set 15 | faya
# Processing Record 50 of Set 15 | almaznyy
# Processing Record 1 of Set 16 | nguiu
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Vaini -21.2000 -175.2000     84.36        65          40
# 1        Jamestown  42.0970  -79.2353     36.72        89          71
# 2           Lumeje -11.5500   20.7833     64.35        95         100
# 3  Arraial Do Cabo -22.9661  -42.0278     72.30        82           4
# 4            Bluff -46.6000  168.3333     52.81        77         100
#
#    Wind Speed Country Current Description
# 0       12.66      TO    scattered clouds
# 1        1.01      US       broken clouds
# 2        2.37      AO     overcast clouds
# 3        9.98      BR           clear sky
# 4       10.80      NZ          light rain

# %%
# Reorder columns so they look the same as the challenge image
city_data_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Vaini      TO -21.2000 -175.2000     84.36        65          40
# 1        Jamestown      US  42.0970  -79.2353     36.72        89          71
# 2           Lumeje      AO -11.5500   20.7833     64.35        95         100
# 3  Arraial Do Cabo      BR -22.9661  -42.0278     72.30        82           4
# 4            Bluff      NZ -46.6000  168.3333     52.81        77         100
# 5           Kwekwe      ZW -18.9281   29.8149     70.81        44          12
# 6       Bredasdorp      ZA -34.5322   20.0403     59.29        95         100
# 7           Albany      US  42.6001  -73.9662     36.68        77          35
# 8        Cape Town      ZA -33.9258   18.4232     63.12        86          75
# 9          Mataura      NZ -46.1927  168.8643     52.48        99         100
#
#    Wind Speed Current Description
# 0       12.66    scattered clouds
# 1        1.01       broken clouds
# 2        2.37     overcast clouds
# 3        9.98           clear sky
# 4       10.80          light rain
# 5        4.32          few clouds
# 6       19.08       moderate rain
# 7        7.92    scattered clouds
# 8       12.66       broken clouds
# 9        4.97          light rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
